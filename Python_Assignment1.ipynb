# %% [markdown]
# Q1. Shopping Cart Item

# %%
item_name="Notebook"
print(item_name)
print(type(item_name))
# Out:
# Notebook
# <class 'str'>

# %%
item_name=101
print(item_name)
print(type(item_name))
# Out:
# 101
# <class 'int'>

# %% [markdown]
# Q2. Student ID Card

# %%
name="Ananya"
roll_number=21
height_in_cm=152.5
is_hostel_student=True

print("Name:",name)
print("Roll Number:",roll_number)
print("Height (in cm):",height_in_cm)
print("Is Hostel Student:",is_hostel_student)
# Out:
# Name: Ananya
# Roll Number: 21
# Height (in cm): 152.5
# Is Hostel Student: True

# %% [markdown]
# Q3. Comparing Two Friends' ages

# %%
sam_age=20
priya_age=20
print(sam_age==priya_age)
print(sam_age is priya_age)
# Out:
# True
# True

# %% [markdown]
# Q4. Fixing a Messy Name

# %%
raw_name="rohan MEHTA"
raw_name= raw_name.strip()
raw_name=raw_name.title()
print(raw_name)
# Out:
# Rohan Mehta

# %% [markdown]
# Q5. Watering Plants Reminder.

# %%
for i in range(1,8):
  print(f" Day{i}:Watered the plant")
# Out:
#  Day1:Watered the plant
#  Day2:Watered the plant
#  Day3:Watered the plant
#  Day4:Watered the plant
#  Day5:Watered the plant
#  Day6:Watered the plant
#  Day7:Watered the plant

# %% [markdown]
# Q6. Counting Down for a Rocket Launch.

# %%
i=5
while i>=1:
  print(i)
  i=i-1

print("Blast off")
# Out:
# 5
# 4
# 3
# 2
# 1
# Blast off

# %% [markdown]
# Q7. Movie Ticket Price.

# %%
age=10
if(age<12):
    print("Ticket price: Rs 100")
else:
  print("Ticket price: Rs 250")
# Out:
# Ticket price: Rs 100

# %% [markdown]
# Q8. Even or Odd Roll Number.

# %%
roll_number=23
if(roll_number%2==0):
  print("Even roll number")
else:
  print("Odd roll number")
# Out:
# Odd roll number

# %% [markdown]
# Q9. Simple Greeting Function.

# %%
def greet_student(name):
  print("Hello,",name,"! Welcome to Python class.")

greet_student("Meera")
greet_student("Karan")
# Out:
# Hello, Meera ! Welcome to Python class.
# Hello, Karan ! Welcome to Python class.

# %% [markdown]
# Q10. Add Two Numbers.

# %%
def add_numbers(a,b):
  return a+b

result=add_numbers(4,7)
print(result)
# Out:
# 11

# %% [markdown]
# Q11. Class Attendance counter.

# %%
total_students=0

def mark_present():
  global total_students
  total_students=total_students+1

mark_present()
mark_present()
mark_present()
print(total_students)
# Out:
# 3
